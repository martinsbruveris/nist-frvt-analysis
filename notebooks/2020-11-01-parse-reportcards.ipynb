# %%
import re
import simplejson as json
from pathlib import Path

import numpy as np
import pandas as pd
from bs4 import BeautifulSoup

# %%
def script_finder(script_id):
    def _finder(tag):
        return (
            (tag.name == "script")
            and tag.has_attr("data-for")
            and (tag.attrs["data-for"] == script_id)
        )
    return _finder

# %%
def parse_fnmr_evolution(data, algorithm):
    df = pd.DataFrame(columns=["algorithm", "dataset", "date", "fmr", "fnmr"])
    
    # Find FMR value
    # Title should be of the form
    # False non-match rate (FNMR) at false match rate (FMR) = 0.000001
    ytitle = data["x"]["layout"]["yaxis"]["title"]["text"]
    fmr = float(re.search(r"\d+\.\d+$", ytitle).group())
    
    fmt = re.compile(
        r"^Submitted: (\d\d\d\d-\d\d-\d\d)<br />fnmr: (\d\.\d+)<br />Dataset: ([\w-]*)$"
    )
    for line in data["x"]["data"]:
        for entry in line["text"]:
            date, fnmr, dataset = fmt.findall(entry)[0]
            row = {
                "algorithm": algorithm, 
                "dataset": dataset, 
                "date": date, 
                "fnmr": fnmr,
                "fmr": fmr
            }
            df = df.append(row, ignore_index=True)
            
    return df

# %%
def parse_cross_region_fmr(data, algorithm):
    df = pd.DataFrame(
            columns=["algorithm", "overall_fmr", "pairing", "eregion", "vregion", "fmr"]
    )
    
    # Find FMR value
    # Title should be of the form
    # <b> Cross region FMR at threshold T = 2.740 for algorithm 3DIVI_003, giving FMR(T) = 0.0001 globally </b>
    title = data["x"]["layout"]["title"]["text"]
    overall_fmr = float(re.findall(r"FMR\(T\) = (\d+\.\d+) globally", title)[0])
    
    
    # Order of the four plots:
    # - Any impostor pairing
    # - Same age impostor
    # - Same sex impostor
    # - Same sex, same age impostor
    pairings = ["any", "same_age", "same_sex", "same_sex_age"]
    plot_idx = 0
    
    for plot in data["x"]["data"]:
        if "hovertext" not in plot:
            continue
        pairing = pairings[plot_idx]
        
        # Each entry is of the form
        # shortfmr0001: -3.3<br />eregion: CARIB<br />vregion: CARIB<br />fmr0001: -3.336707
        fmt = re.compile(
            r"eregion: ([A-Z]+)<br />vregion: ([A-Z]+)<br />fmr[0-9]+: ([-+]\d\.\d+)$"
        )
        for entry in plot["hovertext"]:
            eregion, vregion, fmr = fmt.findall(entry)[0]
            row = {
                "algorithm": algorithm,
                "overall_fmr": overall_fmr,
                "pairing": pairing,
                "eregion": eregion,
                "vregion": vregion,
                "fmr": fmr,
            }
            df = df.append(row, ignore_index=True)
        
        plot_idx += 1
        
    return df

# %%
def parse_plot_title(data, algorithm):
    try:
        title = data["x"]["layout"]["title"]["text"]
    except:
        return None

    if title.endswith("Evolution of accuracy on three datasets 2017 - present<br /> </b>"):
        return "fnmr_evolution"
    elif title.startswith("<b> Cross region FMR"):
        return "cross_region_fmr"
    else:
        return None

# %%
reports_dir = Path("../frvt_pages/reportcards/11")

# %%
res_df = {
    "fnmr_evolution": pd.DataFrame(
            columns=["algorithm", "dataset", "date", "fmr", "fnmr"]
        ),
    "cross_region_fmr": pd.DataFrame(
            columns=["algorithm", "overall_fmr", "pairing", "eregion", "vregion", "fmr"]
    )
}

parsers = {
    "fnmr_evolution": parse_fnmr_evolution,
    "cross_region_fmr": parse_cross_region_fmr,
}

# %%
for filepath in sorted(reports_dir.iterdir()):
    if filepath.suffix != ".html":
        print(filepath)
        continue
    algorithm = filepath.stem.replace("_", "-")
    
    soup = BeautifulSoup(filepath.read_text(), 'lxml')
    plots = soup.find_all("div", attrs="plotly html-widget")

    for plot in plots:
        data = soup.find(script_finder(plot.attrs["id"]))
        data = json.loads(data.contents[0])
        
        plot_type = parse_plot_title(data, algorithm)
        if plot_type is None:
            continue

        try:
            tmp_df = parsers[plot_type](data, algorithm)
        except:
            tmp_df = pd.DataFrame(columns=res_df[plot_type].columns)
        res_df[plot_type] = res_df[plot_type].append(
            tmp_df, ignore_index=True
        )
        print(algorithm, plot_type, len(tmp_df))
# Out:
# 3divi-003 cross_region_fmr 400
# 3divi-004 fnmr_evolution 12
# 3divi-004 cross_region_fmr 400
# 3divi-005 fnmr_evolution 12
# 3divi-005 cross_region_fmr 400
# acer-000 fnmr_evolution 6
# acer-000 cross_region_fmr 400
# acer-001 fnmr_evolution 6
# acer-001 cross_region_fmr 400
# acisw-003 fnmr_evolution 0
# acisw-003 cross_region_fmr 400
# adera-001 fnmr_evolution 0
# adera-001 cross_region_fmr 400
# advance-002 fnmr_evolution 0
# advance-002 cross_region_fmr 400
# aifirst-001 fnmr_evolution 0
# aifirst-001 cross_region_fmr 400
# aigen-001 fnmr_evolution 0
# aigen-001 cross_region_fmr 400
# ailabs-001 fnmr_evolution 0
# ailabs-001 cross_region_fmr 400
# aimall-001 cross_region_fmr 400
# aimall-002 fnmr_evolution 8
# aimall-002 cross_region_fmr 400
# aimall-003 fnmr_evolution 8
# aimall-003 cross_region_fmr 400
# aiunionface-000 fnmr_evolution 0
# aiunionface-000 cross_region_fmr 400
# alchera-000 fnmr_evolution 6
# alchera-000 cross_region_fmr 400
# alchera-001 fnmr_evolution 6
# alchera-001 cross_region_fmr 400
# alleyes-000 fnmr_evolution 0
# alleyes-000 cross_region_fmr 400
# allgovision-000 fnmr_evolution 0
# allgovision-000 cross_region_fmr 400
# alphaface-001 fnmr_evolution 6
# alphaface-001 cross_region_fmr 400
# alphaface-002 fnmr_evolution 6
# alphaface-002 cross_region_fmr 400
# amplifiedgroup-001 fnmr_evolution 0
# amplifiedgroup-001 cross_region_fmr 400
# anke-004 fnmr_evolution 13
# anke-004 cross_region_fmr 400
# anke-005 fnmr_evolution 13
# anke-005 cross_region_fmr 400
# antheus-000 fnmr_evolution 6
# antheus-000 cross_region_fmr 400
# antheus-001 fnmr_evolution 6
# antheus-001 cross_region_fmr 400
# anyvision-002 fnmr_evolution 7
# anyvision-002 cross_region_fmr 400
# anyvision-004 fnmr_evolution 7
# anyvision-004 cross_region_fmr 400
# asusaics-000 fnmr_evolution 6
# asusaics-000 cross_region_fmr 400
# asusaics-001 fnmr_evolution 6
# asusaics-001 cross_region_fmr 400
# aware-004 fnmr_evolution 12
# aware-004 cross_region_fmr 400
# aware-005 fnmr_evolution 12
# aware-005 cross_region_fmr 400
# awiros-001 fnmr_evolution 0
# awiros-001 cross_region_fmr 400
# ayftech-001 fnmr_evolution 0
# ayftech-001 cross_region_fmr 400
# ayonix-000 fnmr_evolution 0
# ayonix-000 cross_region_fmr 400
# bioidtechswiss-000 fnmr_evolution 6
# bioidtechswiss-000 cross_region_fmr 400
# bioidtechswiss-001 fnmr_evolution 6
# bioidtechswiss-001 cross_region_fmr 400
# bm-001 fnmr_evolution 0
# bm-001 cross_region_fmr 400
# bresee-000 fnmr_evolution 0
# bresee-000 cross_region_fmr 400
# camvi-002 fnmr_evolution 9
# camvi-002 cross_region_fmr 400
# camvi-004 fnmr_evolution 9
# camvi-004 cross_region_fmr 400
# ceiec-002 fnmr_evolution 9
# ceiec-002 cross_region_fmr 400
# ceiec-003 fnmr_evolution 9
# ceiec-003 cross_region_fmr 400
# chosun-000 fnmr_evolution 6
# chosun-000 cross_region_fmr 400
# chosun-001 fnmr_evolution 6
# chosun-001 cross_region_fmr 400
# chtface-002 fnmr_evolution 9
# chtface-002 cross_region_fmr 400
# chtface-003 fnmr_evolution 9
# chtface-003 cross_region_fmr 400
# cib-000 fnmr_evolution 6
# cib-000 cross_region_fmr 400
# cib-001 fnmr_evolution 6
# cib-001 cross_region_fmr 400
# cogent-003 fnmr_evolution 10
# cogent-003 cross_region_fmr 400
# cogent-004 fnmr_evolution 10
# cogent-004 cross_region_fmr 400
# cognitec-000 fnmr_evolution 6
# cognitec-000 cross_region_fmr 400
# cognitec-001 fnmr_evolution 6
# cognitec-001 cross_region_fmr 400
# cor-001 fnmr_evolution 0
# cor-001 cross_region_fmr 400
# ctbcbank-000 fnmr_evolution 6
# ctbcbank-000 cross_region_fmr 400
# ctbcbank-001 fnmr_evolution 6
# ctbcbank-001 cross_region_fmr 400
# cuhkee-001 fnmr_evolution 0
# cuhkee-001 cross_region_fmr 400
# cybercore-000 fnmr_evolution 0
# cybercore-000 cross_region_fmr 400
# cyberextruder-001 fnmr_evolution 6
# cyberextruder-001 cross_region_fmr 400
# cyberextruder-002 fnmr_evolution 6
# cyberextruder-002 cross_region_fmr 400
# cyberlink-003 cross_region_fmr 400
# cyberlink-004 fnmr_evolution 17
# cyberlink-004 cross_region_fmr 400
# cyberlink-005 fnmr_evolution 17
# cyberlink-005 cross_region_fmr 400
# dahua-003 cross_region_fmr 400
# dahua-004 fnmr_evolution 15
# dahua-004 cross_region_fmr 400
# dahua-005 fnmr_evolution 15
# dahua-005 cross_region_fmr 400
# decatur-000 fnmr_evolution 0
# decatur-000 cross_region_fmr 400
# deepglint-001 fnmr_evolution 6
# deepglint-001 cross_region_fmr 400
# deepglint-002 fnmr_evolution 6
# deepglint-002 cross_region_fmr 400
# deepsea-001 fnmr_evolution 0
# deepsea-001 cross_region_fmr 400
# dermalog-005 fnmr_evolution 0
# dermalog-005 cross_region_fmr 400
# dermalog-006 fnmr_evolution 0
# dermalog-006 cross_region_fmr 400
# dermalog-007 fnmr_evolution 0
# didiglobalface-001 fnmr_evolution 0
# didiglobalface-001 cross_region_fmr 400
# digitalbarriers-002 fnmr_evolution 0
# digitalbarriers-002 cross_region_fmr 400
# dsk-000 fnmr_evolution 0
# dsk-000 cross_region_fmr 400
# einetworks-000 fnmr_evolution 0
# einetworks-000 cross_region_fmr 400
# eocortex-000 fnmr_evolution 0
# eocortex-000 cross_region_fmr 400
# ercacat-001 fnmr_evolution 0
# ercacat-001 cross_region_fmr 400
# everai-paravision-003 fnmr_evolution 12
# everai-paravision-003 cross_region_fmr 400
# expasoft-000 fnmr_evolution 6
# expasoft-000 cross_region_fmr 400
# expasoft-001 fnmr_evolution 6
# expasoft-001 cross_region_fmr 400
# f8-001 fnmr_evolution 0
# f8-001 cross_region_fmr 400
# facesoft-000 fnmr_evolution 0
# facesoft-000 cross_region_fmr 400
# fiberhome-nanjing-002 fnmr_evolution 0
# fiberhome-nanjing-002 cross_region_fmr 400
# fujitsulab-000 fnmr_evolution 6
# fujitsulab-000 cross_region_fmr 400
# fujitsulab-001 fnmr_evolution 6
# fujitsulab-001 cross_region_fmr 400
# geo-000 fnmr_evolution 0
# geo-000 cross_region_fmr 400
# glory-001 fnmr_evolution 8
# glory-001 cross_region_fmr 400
# glory-002 fnmr_evolution 8
# glory-002 cross_region_fmr 400
# gorilla-004 cross_region_fmr 400
# gorilla-006 fnmr_evolution 16
# gorilla-006 cross_region_fmr 400
# hik-001 fnmr_evolution 0
# hik-001 cross_region_fmr 400
# hr-001 fnmr_evolution 9
# hr-001 cross_region_fmr 400
# hr-002 fnmr_evolution 11
# hr-002 cross_region_fmr 400
# hr-003 fnmr_evolution 11
# icm-000 cross_region_fmr 400
# id3-003 cross_region_fmr 400
# id3-004 fnmr_evolution 11
# id3-004 cross_region_fmr 400
# id3-005 fnmr_evolution 11
# id3-005 cross_region_fmr 400
# idemia-005 fnmr_evolution 16
# idemia-005 cross_region_fmr 400
# idemia-006 fnmr_evolution 16
# idemia-006 cross_region_fmr 400
# iit-001 fnmr_evolution 9
# iit-001 cross_region_fmr 400
# iit-002 fnmr_evolution 9
# iit-002 cross_region_fmr 400
# imagus-000 fnmr_evolution 6
# imagus-000 cross_region_fmr 400
# imagus-001 fnmr_evolution 6
# imagus-001 cross_region_fmr 400
# imagus-002 fnmr_evolution 8
# imagus-002 cross_region_fmr 400
# imperial-000 fnmr_evolution 9
# imperial-000 cross_region_fmr 400
# imperial-002 fnmr_evolution 9
# imperial-002 cross_region_fmr 400
# incode-005 cross_region_fmr 400
# incode-006 fnmr_evolution 19
# incode-006 cross_region_fmr 400
# incode-007 fnmr_evolution 19
# incode-007 cross_region_fmr 400
# innefulabs-000 fnmr_evolution 0
# innefulabs-000 cross_region_fmr 400
# innovativetechnologyltd-001 fnmr_evolution 6
# innovativetechnologyltd-001 cross_region_fmr 400
# innovativetechnologyltd-002 fnmr_evolution 6
# innovativetechnologyltd-002 cross_region_fmr 400
# innovatrics-004 cross_region_fmr 400
# innovatrics-006 fnmr_evolution 15
# innovatrics-006 cross_region_fmr 400
# innovatrics-007 fnmr_evolution 15
# innovatrics-007 cross_region_fmr 400
# intellicloudai-001 fnmr_evolution 0
# intellicloudai-001 cross_region_fmr 400
# intellifusion-001 fnmr_evolution 6
# intellifusion-001 cross_region_fmr 400
# intellifusion-002 fnmr_evolution 6
# intellifusion-002 cross_region_fmr 400
# intellivision-001 fnmr_evolution 6
# intellivision-001 cross_region_fmr 400
# intellivision-002 fnmr_evolution 6
# intellivision-002 cross_region_fmr 400
# intelresearch-000 cross_region_fmr 400
# intelresearch-001 fnmr_evolution 9
# intelresearch-001 cross_region_fmr 400
# intelresearch-002 fnmr_evolution 9
# intelresearch-002 cross_region_fmr 400
# intsysmsu-001 fnmr_evolution 9
# intsysmsu-001 cross_region_fmr 400
# intsysmsu-002 fnmr_evolution 9
# intsysmsu-002 cross_region_fmr 400
# iqface-000 fnmr_evolution 9
# iqface-000 cross_region_fmr 400
# iqface-001 cross_region_fmr 400
# iqface-002 fnmr_evolution 9
# iqface-002 cross_region_fmr 400
# isap-001 fnmr_evolution 6
# isap-001 cross_region_fmr 400
# isap-002 fnmr_evolution 6
# isap-002 cross_region_fmr 400
# isityou-000 fnmr_evolution 0
# isityou-000 cross_region_fmr 400
# isystems-001 fnmr_evolution 7
# isystems-001 cross_region_fmr 400
# isystems-002 fnmr_evolution 7
# isystems-002 cross_region_fmr 400
# itmo-006 fnmr_evolution 13
# itmo-006 cross_region_fmr 400
# itmo-007 fnmr_evolution 13
# itmo-007 cross_region_fmr 400
# iws-000 fnmr_evolution 0
# iws-000 cross_region_fmr 400
# kakao-002 fnmr_evolution 9
# kakao-002 cross_region_fmr 400
# kakao-003 fnmr_evolution 9
# kakao-003 cross_region_fmr 400
# kedacom-000 fnmr_evolution 0
# kedacom-000 cross_region_fmr 400
# kneron-003 fnmr_evolution 6
# kneron-003 cross_region_fmr 400
# kneron-005 fnmr_evolution 6
# kneron-005 cross_region_fmr 400
# kookmin-001 fnmr_evolution 0
# lookman-002 fnmr_evolution 6
# lookman-002 cross_region_fmr 400
# lookman-004 fnmr_evolution 6
# lookman-004 cross_region_fmr 400
# luxand-000 fnmr_evolution 0
# luxand-000 cross_region_fmr 400
# megvii-001 fnmr_evolution 7
# megvii-001 cross_region_fmr 400
# megvii-002 fnmr_evolution 7
# megvii-002 cross_region_fmr 400
# meiya-001 fnmr_evolution 0
# meiya-001 cross_region_fmr 400
# microfocus-001 fnmr_evolution 7
# microfocus-001 cross_region_fmr 400
# microfocus-002 fnmr_evolution 7
# microfocus-002 cross_region_fmr 400
# mobai-000 fnmr_evolution 0
# mobai-000 cross_region_fmr 400
# mt-000 fnmr_evolution 6
# mt-000 cross_region_fmr 400
# mt-002 fnmr_evolution 6
# mt-002 cross_region_fmr 400
# mvision-001 fnmr_evolution 0
# mvision-001 cross_region_fmr 400
# nazhiai-000 fnmr_evolution 0
# nazhiai-000 cross_region_fmr 400
# neemtecsolutions-001 cross_region_fmr 400
# netbridgetech-001 fnmr_evolution 6
# netbridgetech-001 cross_region_fmr 400
# netbridgetech-002 fnmr_evolution 6
# netbridgetech-002 cross_region_fmr 400
# neurotechnology-008 fnmr_evolution 18
# neurotechnology-008 cross_region_fmr 400
# neurotechnology-009 fnmr_evolution 18
# neurotechnology-009 cross_region_fmr 400
# nodeflux-002 fnmr_evolution 9
# nodeflux-002 cross_region_fmr 400
# notiontag-000 fnmr_evolution 0
# notiontag-000 cross_region_fmr 400
# ntechlab-007 fnmr_evolution 16
# ntechlab-007 cross_region_fmr 400
# ntechlab-008 fnmr_evolution 16
# ntechlab-008 cross_region_fmr 400
# oz-001 fnmr_evolution 0
# oz-001 cross_region_fmr 400
# paravision-004 fnmr_evolution 12
# paravision-004 cross_region_fmr 400
# pensees-001 fnmr_evolution 0
# pensees-001 cross_region_fmr 400
# pixelall-003 fnmr_evolution 9
# pixelall-003 cross_region_fmr 400
# pixelall-004 fnmr_evolution 9
# pixelall-004 cross_region_fmr 400
# ../frvt_pages/reportcards/11/plotly_lib
# psl-003 fnmr_evolution 15
# psl-003 cross_region_fmr 400
# psl-005 fnmr_evolution 15
# psl-005 cross_region_fmr 400
# ptakuratsatu-000 fnmr_evolution 0
# ptakuratsatu-000 cross_region_fmr 400
# pxl-001 fnmr_evolution 0
# pxl-001 cross_region_fmr 400
# pyramid-000 fnmr_evolution 0
# pyramid-000 cross_region_fmr 400
# rankone-008 fnmr_evolution 19
# rankone-008 cross_region_fmr 400
# rankone-009 fnmr_evolution 19
# rankone-009 cross_region_fmr 400
# realnetworks-002 fnmr_evolution 9
# realnetworks-002 cross_region_fmr 400
# realnetworks-003 fnmr_evolution 9
# realnetworks-003 cross_region_fmr 400
# remarkai-001 fnmr_evolution 9
# remarkai-001 cross_region_fmr 400
# remarkai-002 fnmr_evolution 9
# remarkai-002 cross_region_fmr 400
# rokid-000 fnmr_evolution 6
# rokid-000 cross_region_fmr 400
# rokid-001 fnmr_evolution 6
# rokid-001 cross_region_fmr 400
# s1-001 fnmr_evolution 0
# s1-001 cross_region_fmr 400
# saffe-001 fnmr_evolution 6
# saffe-001 cross_region_fmr 400
# saffe-002 fnmr_evolution 6
# saffe-002 cross_region_fmr 400
# samtech-001 fnmr_evolution 0
# samtech-001 cross_region_fmr 400
# scanovate-001 fnmr_evolution 6
# scanovate-001 cross_region_fmr 400
# scanovate-002 fnmr_evolution 6
# scanovate-002 cross_region_fmr 400
# securifai-001 fnmr_evolution 0
# securifai-001 cross_region_fmr 400
# sensetime-002 fnmr_evolution 17
# sensetime-002 cross_region_fmr 400
# sensetime-003 fnmr_evolution 17
# sensetime-003 cross_region_fmr 400
# sertis-000 fnmr_evolution 6
# sertis-000 cross_region_fmr 400
# sertis-001 fnmr_evolution 6
# sertis-001 cross_region_fmr 400
# shaman-000 fnmr_evolution 6
# shaman-000 cross_region_fmr 400
# shaman-001 fnmr_evolution 6
# shaman-001 cross_region_fmr 400
# shu-002 fnmr_evolution 9
# shu-002 cross_region_fmr 400
# shu-003 fnmr_evolution 9
# shu-003 cross_region_fmr 400
# siat-002 fnmr_evolution 17
# siat-002 cross_region_fmr 400
# siat-004 fnmr_evolution 17
# siat-004 cross_region_fmr 400
# sjtu-001 fnmr_evolution 6
# sjtu-001 cross_region_fmr 400
# sjtu-002 fnmr_evolution 6
# sjtu-002 cross_region_fmr 400
# smilart-002 fnmr_evolution 0
# smilart-002 cross_region_fmr 400
# smilart-003 fnmr_evolution 0
# smilart-003 cross_region_fmr 400
# staqu-000 fnmr_evolution 0
# staqu-000 cross_region_fmr 400
# starhybrid-001 fnmr_evolution 0
# starhybrid-001 cross_region_fmr 400
# synesis-006 fnmr_evolution 15
# synesis-006 cross_region_fmr 400
# synesis-007 fnmr_evolution 15
# synesis-007 cross_region_fmr 400
# synology-000 fnmr_evolution 9
# synology-000 cross_region_fmr 400
# synology-001 cross_region_fmr 400
# synology-002 fnmr_evolution 9
# synology-002 cross_region_fmr 400
# tech5-003 cross_region_fmr 400
# tech5-004 fnmr_evolution 16
# tech5-004 cross_region_fmr 400
# tech5-005 fnmr_evolution 16
# tech5-005 cross_region_fmr 400
# tevian-004 cross_region_fmr 400
# tevian-005 fnmr_evolution 14
# tevian-005 cross_region_fmr 400
# tevian-006 fnmr_evolution 14
# tiger-002 fnmr_evolution 7
# tiger-002 cross_region_fmr 400
# tiger-003 fnmr_evolution 7
# tiger-003 cross_region_fmr 400
# tongyi-005 fnmr_evolution 0
# tongyi-005 cross_region_fmr 400
# toshiba-002 fnmr_evolution 6
# toshiba-002 cross_region_fmr 400
# toshiba-003 fnmr_evolution 6
# toshiba-003 cross_region_fmr 400
# trueface-000 fnmr_evolution 6
# trueface-000 cross_region_fmr 400
# trueface-001 fnmr_evolution 6
# trueface-001 cross_region_fmr 400
# tuputech-000 fnmr_evolution 0
# tuputech-000 cross_region_fmr 400
# ulsee-001 fnmr_evolution 0
# ulsee-001 cross_region_fmr 400
# ultinous-000 fnmr_evolution 2
# ultinous-000 cross_region_fmr 400
# ultinous-001 fnmr_evolution 2
# ultinous-001 cross_region_fmr 400
# uluface-002 fnmr_evolution 0
# uluface-002 cross_region_fmr 400
# uluface-003 fnmr_evolution 0
# uluface-003 cross_region_fmr 400
# upc-001 fnmr_evolution 0
# upc-001 cross_region_fmr 400
# vcog-002 fnmr_evolution 0
# vcog-002 cross_region_fmr 400
# vd-001 fnmr_evolution 0
# vd-001 cross_region_fmr 400
# veridas-003 fnmr_evolution 12
# veridas-003 cross_region_fmr 400
# veridas-004 fnmr_evolution 12
# veridas-004 cross_region_fmr 400
# via-000 fnmr_evolution 6
# via-000 cross_region_fmr 400
# via-001 fnmr_evolution 6
# via-001 cross_region_fmr 400
# videmo-000 fnmr_evolution 0
# videmo-000 cross_region_fmr 400
# videonetics-001 fnmr_evolution 6
# videonetics-001 cross_region_fmr 400
# videonetics-002 fnmr_evolution 6
# videonetics-002 cross_region_fmr 400
# vigilantsolutions-006 cross_region_fmr 400
# vigilantsolutions-007 fnmr_evolution 17
# vigilantsolutions-007 cross_region_fmr 400
# vigilantsolutions-008 fnmr_evolution 17
# vigilantsolutions-008 cross_region_fmr 400
# vinai-000 fnmr_evolution 0
# vinai-000 cross_region_fmr 400
# vion-000 fnmr_evolution 0
# vion-000 cross_region_fmr 400
# visionbox-000 fnmr_evolution 6
# visionbox-000 cross_region_fmr 400
# visionbox-001 fnmr_evolution 6
# visionbox-001 cross_region_fmr 400
# visionlabs-007 cross_region_fmr 400
# visionlabs-008 fnmr_evolution 18
# visionlabs-008 cross_region_fmr 400
# visionlabs-009 fnmr_evolution 18
# visionlabs-009 cross_region_fmr 400
# visteam-000 fnmr_evolution 0
# visteam-000 cross_region_fmr 400
# vocord-007 fnmr_evolution 16
# vocord-007 cross_region_fmr 400
# vocord-008 fnmr_evolution 16
# vocord-008 cross_region_fmr 400
# winsense-000 fnmr_evolution 6
# winsense-000 cross_region_fmr 400
# winsense-001 fnmr_evolution 6
# winsense-001 cross_region_fmr 400
# x-laboratory-000 fnmr_evolution 6
# x-laboratory-000 cross_region_fmr 400
# x-laboratory-001 fnmr_evolution 6
# x-laboratory-001 cross_region_fmr 400
# xforwardai-000 fnmr_evolution 6
# xforwardai-000 cross_region_fmr 400
# yisheng-004 fnmr_evolution 0
# yisheng-004 cross_region_fmr 400
# yitu-003 fnmr_evolution 0
# yitu-003 cross_region_fmr 400
# yoonik-000 fnmr_evolution 0
# yoonik-000 cross_region_fmr 400
# yuan-000 fnmr_evolution 0
# yuan-000 cross_region_fmr 400

# %%
res_df["fnmr_evolution"].to_csv("../data/frvt_11_fnmr_evolution.csv", index=False)

# %%
res_df["cross_region_fmr"].to_csv("../data/frvt_11_cross_region_fmr.csv", index=False)
